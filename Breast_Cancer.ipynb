# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# This analysis aims to observe which features are most helpful in predicting malignant or benign cancer  it is classification problem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.drop('Unnamed: 32',axis=1,inplace=True)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D2C261630>,
# ...
#       dtype=object)

# %%
df.isnull().summ()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# convert categorial column value of diagonis into boolean ovalue
# M = malignant or B = benign. 1 means the cancer is malignant and 0 means benign

# %%
df['diagnosis']=pd.get_dummies(df['diagnosis'])

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          0        17.99         10.38          122.80     1001.0
# 1    842517          0        20.57         17.77          132.90     1326.0
# 2  84300903          0        19.69         21.25          130.00     1203.0
# 3  84348301          0        11.42         20.38           77.58      386.1
# 4  84358402          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# 1    357
# 0    212
# Name: diagnosis, dtype: int64

# %%
# creating dataset
X = df.iloc[:,1:31]
Y = df.iloc[:, 31]

# %%
X.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  fractal_dimension_se  radius_worst  texture_worst  \
# ...

# %%
Y
# Out:
# 0      0.11890
# 1      0.08902
# 2      0.08758
# 3      0.17300
# 4      0.07678
# 5      0.12440
# 6      0.08368
# 7      0.11510
# 8      0.10720
# 9      0.20750
# 10     0.08452
# 11     0.10480
# 12     0.10230
# 13     0.06287
# 14     0.14310
# 15     0.13410
# 16     0.08216
# 17     0.11420
# 18     0.07615
# 19     0.07259
# 20     0.08183
# 21     0.07773
# 22     0.09946
# 23     0.07526
# 24     0.09564
# 25     0.10590
# 26     0.12750
# 27     0.07421
# 28     0.09876
# 29     0.07919
#         ...
# 539    0.10660
# 540    0.08134
# 541    0.10230
# 542    0.06956
# 543    0.06443
# 544    0.08492
# 545    0.06953
# 546    0.07399
# 547    0.09479
# 548    0.07920
# 549    0.07626
# 550    0.06592
# 551    0.08032
# 552    0.06484
# 553    0.07393
# 554    0.07242
# 555    0.08283
# 556    0.06742
# 557    0.06969
# 558    0.08004
# 559    0.08732
# 560    0.08321
# 561    0.05905
# 562    0.14090
# 563    0.09873
# 564    0.07115
# 565    0.06637
# 566    0.07820
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
model=LogisticRegression()

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-ffa49499a3bf> in <module>
# ----> 1 model.fit(X_train,Y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1288                          accept_large_sparse=solver != 'liblinear')
# -> 1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#    1291         n_samples, n_features = X.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...

# %%
print('intercept b0',model.intercept_)
print('slope of line b1',model.coef_)
# Out:
# intercept b0 -0.012376327999830489
# slope of line b1 [-1.12190416e-03 -1.82351829e-03 -2.65991730e-05  2.74767841e-04
#  -1.27081877e-06 -4.91117088e-02 -9.71009284e-02 -2.79353854e-02
#   1.34674209e-02 -5.20336360e-03  1.25348510e+00 -1.77647732e-02
#  -7.63517902e-04  2.14603232e-03  2.79601452e-05  9.46128026e-02
#  -1.89208885e-01 -1.26867301e-01  4.78052943e-03 -1.93141003e-01
#   2.94526745e+00  3.70391152e-03  7.51210938e-05 -5.44415608e-04
#  -3.35708269e-07  3.24987779e-02  7.70631234e-02  3.09293821e-02
#  -1.86975687e-02  2.03940022e-02]

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([0.06546184, 0.11004076, 0.074926  , 0.0867466 , 0.07406499,
#        0.07599878, 0.0809541 , 0.08009441, 0.06683085, 0.07541534,
#        0.11928316, 0.08005918, 0.10021381, 0.06669803, 0.10299517,
#        0.06750375, 0.09045786, 0.11594398, 0.07558273, 0.07661217,
#        0.10205708, 0.07024492, 0.09455646, 0.07312898, 0.07945634,
#        0.07101344, 0.06480298, 0.06996785, 0.11134186, 0.08822912,
#        0.09898896, 0.07307389, 0.07545892, 0.06184324, 0.09421177,
#        0.06037336, 0.07131134, 0.08046891, 0.09052539, 0.09269305,
#        0.06575383, 0.08019675, 0.09480014, 0.09675302, 0.06658203,
#        0.08449197, 0.1052081 , 0.05808187, 0.07548922, 0.0679382 ,
#        0.07545506, 0.09160106, 0.08416657, 0.062926  , 0.08026295,
#        0.05557964, 0.12104705, 0.06045081, 0.07875505, 0.0777375 ,
#        0.06494951, 0.11725241, 0.08079952, 0.05566503, 0.09085248,
#        0.07129996, 0.08843757, 0.0998018 , 0.1245311 , 0.08667532,
# ...
